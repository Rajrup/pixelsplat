# %%
import torch

# %%
a = torch.load(
    "/main/rajrup/Dropbox/Project/GsplatStream/LivoGstream/src/pixelsplat/datasets/acid_subset/test/000000.torch"
)

# %%
a
# Out:
# [{'url': 'https://www.youtube.com/watch?v=dvLLtJJ68kI',
#   'timestamps': tensor([80466667, 80500000, 80533333, 80566667, 80600000, 80633333, 80666667,
#           80700000, 80733333, 80766667, 80800000, 80833333, 80866667, 80900000,
#           80933333, 80966667, 81000000, 81033333, 81066667]),
#   'cameras': tensor([[ 5.0167e-01,  8.9186e-01,  5.0000e-01,  5.0000e-01,  0.0000e+00,
#             0.0000e+00,  9.9993e-01,  1.1358e-02, -2.6475e-03, -4.8363e-03,
#            -1.1340e-02,  9.9991e-01,  6.9331e-03,  1.4274e-01,  2.7260e-03,
#            -6.9026e-03,  9.9997e-01,  1.5705e-02],
#           [ 5.0167e-01,  8.9186e-01,  5.0000e-01,  5.0000e-01,  0.0000e+00,
#             0.0000e+00,  9.9993e-01,  1.1446e-02, -2.6714e-03, -4.5546e-03,
#            -1.1429e-02,  9.9991e-01,  6.3656e-03,  1.4890e-01,  2.7440e-03,
#            -6.3347e-03,  9.9998e-01,  1.6036e-02],
#           [ 5.0167e-01,  8.9186e-01,  5.0000e-01,  5.0000e-01,  0.0000e+00,
# ...
